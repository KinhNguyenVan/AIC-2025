# %%
from qdrant_client import models
from qdrant_client import QdrantClient
import os
from dotenv import load_dotenv
load_dotenv()

# os.environ["HF_HOME"] = "D:/huggingface"
# os.environ["TRANSFORMERS_CACHE"] = "D:/huggingface/transformers"
# from src.search.model import CLIPModel


# embedding = CLIPModel()

# text = """A chef puts fish into a white bowl at the exact moment the last fish falls from the plate, then pours flour into the bowl of fish with chopsticks touching the fish for the first time to mix, and finally tests the temperature of hot oil with chopsticks at the moment they are first lifted out of the oil.
# """

# text_features = embedding.encode_text(text)
qdrant_client =QdrantClient(
    url=os.getenv("OCR_QDRANT_URL"),
    api_key=os.getenv("OCR_QDRANT_API_KEY"),
    timeout=60.0   
)

qdrant_client.create_payload_index(
    collection_name="ocr_collection",
    field_name="path",
    field_schema=models.PayloadSchemaType.TEXT
)

# qdrant_client.delete(
#     collection_name="image_clip_vectors",
#     points_selector=models.FilterSelector(
#         filter=models.Filter(
#             must=[
#                 models.FieldCondition(
#                     key="path",
#                     match=models.MatchText(text="K11_V020")
#                 )
#             ]
#         )
#     )
# )
# Out:
# UpdateResult(operation_id=47421, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
text = """A dog
"""

text_features = embedding.encode_text(text)
video_ids = ["Keyframes_K01", "Keyframes_K02", "Keyframes_K03", "Keyframes_K04"]
search_result = qdrant_client.search(
    collection_name="image_clip_vectors",
    query_vector=text_features.squeeze().tolist(),
    limit=200,
    with_payload=True,
    query_filter=models.Filter(
        should=[
            models.FieldCondition(
                key="path",
                match=models.MatchText(text=vid)
            )
            for vid in video_ids
        ]
    ),
    search_params=models.SearchParams(
        hnsw_ef=500,
        # exact=True
        ),
    timeout=60

)
for hit in search_result:
    print(hit.payload, hit.score)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4772\4222562216.py:6: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   search_result = qdrant_client.search(
# {'path': 'Keyframes_K01/K01_V021/023163.webp'} 0.12860355
# {'path': 'Keyframes_K04/K04_V010/010025.webp'} 0.1262478
# {'path': 'Keyframes_K04/K04_V021/016954.webp'} 0.12560609
# {'path': 'Keyframes_K02/K02_V003/028766.webp'} 0.12479419
# {'path': 'Keyframes_K01/K01_V021/023236.webp'} 0.12478252
# {'path': 'Keyframes_K01/K01_V021/023091.webp'} 0.124610566
# {'path': 'Keyframes_K04/K04_V010/010045.webp'} 0.124552116
# {'path': 'Keyframes_K02/K02_V003/028835.webp'} 0.1242302
# {'path': 'Keyframes_K04/K04_V010/010065.webp'} 0.12362447
# {'path': 'Keyframes_K04/K04_V010/009987.webp'} 0.12342438
# {'path': 'Keyframes_K03/K03_V001/029469.webp'} 0.12219411
# {'path': 'Keyframes_K03/K03_V001/028457.webp'} 0.12166904
# {'path': 'Keyframes_K04/K04_V010/010006.webp'} 0.121620126
# {'path': 'Keyframes_K03/K03_V001/029522.webp'} 0.12055615
# {'path': 'Keyframes_K01/K01_V029/022040.webp'} 0.12026704
# {'path': 'Keyframes_K02/K02_V003/028904.webp'} 0.120262146
# {'path': 'Keyframes_K04/K04_V021/012879.webp'} 0.12009766
# {'path': 'Keyframes_K01/K01_V020/022480.webp'} 0.11994721
# {'path': 'Keyframes_K01/K01_V020/022314.webp'} 0.1199118
# {'path': 'Keyframes_K04/K04_V021/012860.webp'} 0.11975761
# {'path': 'Keyframes_K04/K04_V021/017539.webp'} 0.11964475
# {'path': 'Keyframes_K01/K01_V005/013621.webp'} 0.119251825
# {'path': 'Keyframes_K03/K03_V001/029495.webp'} 0.11920567
# {'path': 'Keyframes_K04/K04_V021/017484.webp'} 0.118561685
# {'path': 'Keyframes_K02/K02_V003/028982.webp'} 0.11832057
# {'path': 'Keyframes_K04/K04_V010/010103.webp'} 0.11830722
# {'path': 'Keyframes_K04/K04_V021/012928.webp'} 0.11823797
# {'path': 'Keyframes_K02/K02_V025/030263.webp'} 0.11822492
# {'path': 'Keyframes_K01/K01_V005/009705.webp'} 0.11805758
# {'path': 'Keyframes_K04/K04_V026/017403.webp'} 0.11800201
# {'path': 'Keyframes_K01/K01_V019/019396.webp'} 0.11789255
# {'path': 'Keyframes_K02/K02_V002/022621.webp'} 0.117742136
# {'path': 'Keyframes_K04/K04_V027/001624.webp'} 0.11755663
# {'path': 'Keyframes_K03/K03_V001/029228.webp'} 0.11747504
# {'path': 'Keyframes_K04/K04_V021/016978.webp'} 0.11736347
# {'path': 'Keyframes_K04/K04_V026/017417.webp'} 0.11733368
# {'path': 'Keyframes_K01/K01_V005/013175.webp'} 0.1172436
# {'path': 'Keyframes_K02/K02_V003/027645.webp'} 0.117168196
# {'path': 'Keyframes_K04/K04_V010/009486.webp'} 0.11713666
# {'path': 'Keyframes_K01/K01_V020/022397.webp'} 0.116922125
# {'path': 'Keyframes_K01/K01_V005/013427.webp'} 0.116885394
# {'path': 'Keyframes_K04/K04_V010/010095.webp'} 0.11654693
# {'path': 'Keyframes_K04/K04_V021/012899.webp'} 0.11651504
# {'path': 'Keyframes_K04/K04_V010/009409.webp'} 0.11636338
# {'path': 'Keyframes_K02/K02_V005/019919.webp'} 0.11636214
# {'path': 'Keyframes_K03/K03_V001/028371.webp'} 0.116290554
# {'path': 'Keyframes_K04/K04_V017/030654.webp'} 0.11620032
# {'path': 'Keyframes_K01/K01_V029/026359.webp'} 0.11596209
# {'path': 'Keyframes_K04/K04_V003/023684.webp'} 0.11588727
# {'path': 'Keyframes_K04/K04_V021/012913.webp'} 0.11569725
# {'path': 'Keyframes_K04/K04_V026/017432.webp'} 0.115257055
# {'path': 'Keyframes_K01/K01_V007/022045.webp'} 0.1150731
# {'path': 'Keyframes_K01/K01_V020/022604.webp'} 0.115045145
# {'path': 'Keyframes_K04/K04_V003/024104.webp'} 0.114723995
# {'path': 'Keyframes_K01/K01_V005/013245.webp'} 0.11455005
# {'path': 'Keyframes_K04/K04_V003/024162.webp'} 0.11449635
# {'path': 'Keyframes_K03/K03_V005/025218.webp'} 0.11439805
# {'path': 'Keyframes_K01/K01_V005/013411.webp'} 0.11438531
# {'path': 'Keyframes_K01/K01_V019/019308.webp'} 0.11417658
# {'path': 'Keyframes_K02/K02_V020/016505.webp'} 0.11409369
# {'path': 'Keyframes_K04/K04_V010/010111.webp'} 0.113866925
# {'path': 'Keyframes_K04/K04_V003/024221.webp'} 0.11364509
# {'path': 'Keyframes_K01/K01_V019/019371.webp'} 0.11352615
# {'path': 'Keyframes_K02/K02_V020/016448.webp'} 0.113313235
# {'path': 'Keyframes_K01/K01_V007/022149.webp'} 0.113275096
# {'path': 'Keyframes_K03/K03_V005/025244.webp'} 0.113122605
# {'path': 'Keyframes_K04/K04_V021/017195.webp'} 0.113090135
# {'path': 'Keyframes_K04/K04_V021/012898.webp'} 0.11286286
# {'path': 'Keyframes_K04/K04_V017/031133.webp'} 0.112862006
# {'path': 'Keyframes_K01/K01_V020/021951.webp'} 0.11282713
# {'path': 'Keyframes_K04/K04_V010/009360.webp'} 0.112774804
# {'path': 'Keyframes_K01/K01_V020/022068.webp'} 0.11275062
# {'path': 'Keyframes_K02/K02_V003/018999.webp'} 0.11270673
# {'path': 'Keyframes_K04/K04_V021/017428.webp'} 0.112528145
# {'path': 'Keyframes_K04/K04_V010/009312.webp'} 0.11238582
# {'path': 'Keyframes_K02/K02_V030/014818.webp'} 0.11226978
# {'path': 'Keyframes_K04/K04_V021/017306.webp'} 0.112192705
# {'path': 'Keyframes_K02/K02_V025/030207.webp'} 0.1117195
# {'path': 'Keyframes_K04/K04_V021/017429.webp'} 0.1114236
# {'path': 'Keyframes_K04/K04_V003/024668.webp'} 0.1114103
# {'path': 'Keyframes_K04/K04_V010/010066.webp'} 0.110926256
# {'path': 'Keyframes_K02/K02_V020/016392.webp'} 0.11090024
# {'path': 'Keyframes_K01/K01_V005/009690.webp'} 0.11071526
# {'path': 'Keyframes_K04/K04_V010/009502.webp'} 0.11066582
# {'path': 'Keyframes_K01/K01_V020/021817.webp'} 0.11064443
# {'path': 'Keyframes_K01/K01_V005/013105.webp'} 0.11057707
# {'path': 'Keyframes_K01/K01_V012/001466.webp'} 0.11056241
# {'path': 'Keyframes_K02/K02_V025/021882.webp'} 0.1103699
# {'path': 'Keyframes_K04/K04_V021/017767.webp'} 0.11018858
# {'path': 'Keyframes_K01/K01_V011/015223.webp'} 0.110118106
# {'path': 'Keyframes_K01/K01_V007/022125.webp'} 0.110053405
# {'path': 'Keyframes_K04/K04_V010/009699.webp'} 0.10979939
# {'path': 'Keyframes_K03/K03_V019/027651.webp'} 0.10964766
# {'path': 'Keyframes_K03/K03_V005/025193.webp'} 0.10950351
# {'path': 'Keyframes_K01/K01_V005/013670.webp'} 0.10942819
# {'path': 'Keyframes_K01/K01_V007/021988.webp'} 0.10938494
# {'path': 'Keyframes_K04/K04_V003/023433.webp'} 0.10932894
# {'path': 'Keyframes_K02/K02_V020/016923.webp'} 0.10925692
# {'path': 'Keyframes_K01/K01_V020/022603.webp'} 0.10923226
# {'path': 'Keyframes_K01/K01_V020/022067.webp'} 0.10919818
# {'path': 'Keyframes_K04/K04_V003/013764.webp'} 0.109159246
# {'path': 'Keyframes_K01/K01_V020/022632.webp'} 0.10912345
# {'path': 'Keyframes_K03/K03_V005/025320.webp'} 0.10901642
# {'path': 'Keyframes_K02/K02_V002/022642.webp'} 0.10892511
# {'path': 'Keyframes_K04/K04_V021/017305.webp'} 0.10888088
# {'path': 'Keyframes_K03/K03_V018/025528.webp'} 0.10881862
# {'path': 'Keyframes_K01/K01_V020/022991.webp'} 0.10866453
# {'path': 'Keyframes_K03/K03_V005/024415.webp'} 0.10864617
# {'path': 'Keyframes_K03/K03_V001/029396.webp'} 0.108614594
# {'path': 'Keyframes_K01/K01_V005/013062.webp'} 0.10859299
# {'path': 'Keyframes_K04/K04_V021/017733.webp'} 0.10850969
# {'path': 'Keyframes_K04/K04_V003/023836.webp'} 0.10844254
# {'path': 'Keyframes_K04/K04_V010/009944.webp'} 0.1084158
# {'path': 'Keyframes_K01/K01_V020/023154.webp'} 0.10826659
# {'path': 'Keyframes_K04/K04_V003/023635.webp'} 0.10817139
# {'path': 'Keyframes_K03/K03_V019/027694.webp'} 0.10807298
# {'path': 'Keyframes_K04/K04_V021/017003.webp'} 0.10792606
# {'path': 'Keyframes_K04/K04_V003/024528.webp'} 0.10780625
# {'path': 'Keyframes_K03/K03_V005/024390.webp'} 0.107731506
# {'path': 'Keyframes_K02/K02_V011/026125.webp'} 0.10761738
# {'path': 'Keyframes_K01/K01_V007/022102.webp'} 0.10759729
# {'path': 'Keyframes_K02/K02_V005/000611.webp'} 0.107592836
# {'path': 'Keyframes_K04/K04_V010/009630.webp'} 0.10756777
# {'path': 'Keyframes_K02/K02_V005/019861.webp'} 0.10739147
# {'path': 'Keyframes_K03/K03_V001/029368.webp'} 0.10733771
# {'path': 'Keyframes_K04/K04_V021/012859.webp'} 0.10731141
# {'path': 'Keyframes_K02/K02_V025/030073.webp'} 0.107263304
# {'path': 'Keyframes_K04/K04_V010/009986.webp'} 0.10725081
# {'path': 'Keyframes_K01/K01_V019/019346.webp'} 0.107197195
# {'path': 'Keyframes_K04/K04_V010/009065.webp'} 0.10719532
# {'path': 'Keyframes_K04/K04_V010/009665.webp'} 0.10714261
# {'path': 'Keyframes_K04/K04_V010/009965.webp'} 0.10709001
# {'path': 'Keyframes_K02/K02_V005/020566.webp'} 0.10706435
# {'path': 'Keyframes_K01/K01_V005/012319.webp'} 0.10704144
# {'path': 'Keyframes_K03/K03_V001/028793.webp'} 0.1069908
# {'path': 'Keyframes_K01/K01_V005/009592.webp'} 0.10681675
# {'path': 'Keyframes_K01/K01_V020/021613.webp'} 0.1067925
# {'path': 'Keyframes_K03/K03_V018/025447.webp'} 0.106527165
# {'path': 'Keyframes_K04/K04_V021/012837.webp'} 0.10637388
# {'path': 'Keyframes_K01/K01_V005/011589.webp'} 0.10636455
# {'path': 'Keyframes_K04/K04_V010/009519.webp'} 0.10628991
# {'path': 'Keyframes_K02/K02_V025/030853.webp'} 0.106256224
# {'path': 'Keyframes_K01/K01_V005/013020.webp'} 0.10616159
# {'path': 'Keyframes_K03/K03_V001/029340.webp'} 0.10614157
# {'path': 'Keyframes_K01/K01_V013/019473.webp'} 0.106130674
# {'path': 'Keyframes_K04/K04_V003/023529.webp'} 0.106012456
# {'path': 'Keyframes_K01/K01_V005/009577.webp'} 0.10592902
# {'path': 'Keyframes_K02/K02_V025/021920.webp'} 0.105842896
# {'path': 'Keyframes_K01/K01_V029/026333.webp'} 0.10579751
# {'path': 'Keyframes_K02/K02_V020/016887.webp'} 0.1056813
# {'path': 'Keyframes_K02/K02_V005/019862.webp'} 0.10562383
# {'path': 'Keyframes_K04/K04_V010/010094.webp'} 0.10560685
# {'path': 'Keyframes_K03/K03_V005/024440.webp'} 0.10550979
# {'path': 'Keyframes_K04/K04_V014/018324.webp'} 0.10550603
# {'path': 'Keyframes_K03/K03_V001/029432.webp'} 0.10540357
# {'path': 'Keyframes_K04/K04_V017/030903.webp'} 0.10540103
# {'path': 'Keyframes_K01/K01_V007/021958.webp'} 0.105387226
# {'path': 'Keyframes_K02/K02_V005/019890.webp'} 0.10537171
# {'path': 'Keyframes_K04/K04_V010/009647.webp'} 0.105347484
# {'path': 'Keyframes_K04/K04_V021/016953.webp'} 0.10531784
# {'path': 'Keyframes_K04/K04_V003/023588.webp'} 0.10526026
# {'path': 'Keyframes_K04/K04_V003/023528.webp'} 0.10518132
# {'path': 'Keyframes_K03/K03_V029/029346.webp'} 0.105175875
# {'path': 'Keyframes_K01/K01_V011/014972.webp'} 0.104943596
# {'path': 'Keyframes_K01/K01_V005/012350.webp'} 0.10488728
# {'path': 'Keyframes_K04/K04_V003/024074.webp'} 0.10471385
# {'path': 'Keyframes_K02/K02_V028/026428.webp'} 0.10466883
# {'path': 'Keyframes_K04/K04_V021/016882.webp'} 0.104622655
# {'path': 'Keyframes_K02/K02_V028/026957.webp'} 0.10459952
# {'path': 'Keyframes_K02/K02_V005/020149.webp'} 0.10458666
# {'path': 'Keyframes_K02/K02_V005/020136.webp'} 0.104467206
# {'path': 'Keyframes_K01/K01_V005/013104.webp'} 0.10445042
# {'path': 'Keyframes_K02/K02_V005/000573.webp'} 0.10440025
# {'path': 'Keyframes_K04/K04_V021/012848.webp'} 0.10437651
# {'path': 'Keyframes_K01/K01_V005/013573.webp'} 0.104372665
# {'path': 'Keyframes_K02/K02_V025/021901.webp'} 0.10436475
# {'path': 'Keyframes_K03/K03_V029/030058.webp'} 0.10430628
# {'path': 'Keyframes_K01/K01_V020/023074.webp'} 0.10421993
# {'path': 'Keyframes_K03/K03_V001/028581.webp'} 0.10413252
# {'path': 'Keyframes_K03/K03_V005/025488.webp'} 0.10410582
# {'path': 'Keyframes_K01/K01_V007/022016.webp'} 0.103921846
# {'path': 'Keyframes_K01/K01_V005/013443.webp'} 0.10389395
# {'path': 'Keyframes_K03/K03_V019/027672.webp'} 0.10388726
# {'path': 'Keyframes_K03/K03_V005/025282.webp'} 0.10387945
# {'path': 'Keyframes_K01/K01_V005/012381.webp'} 0.10380156
# {'path': 'Keyframes_K02/K02_V020/016022.webp'} 0.10377048
# {'path': 'Keyframes_K04/K04_V010/009734.webp'} 0.10375923
# {'path': 'Keyframes_K02/K02_V005/020611.webp'} 0.103753224
# {'path': 'Keyframes_K03/K03_V001/029397.webp'} 0.10369673
# {'path': 'Keyframes_K03/K03_V005/024310.webp'} 0.10369305
# {'path': 'Keyframes_K04/K04_V003/024046.webp'} 0.10351041
# {'path': 'Keyframes_K03/K03_V005/024391.webp'} 0.103413925
# {'path': 'Keyframes_K02/K02_V025/030786.webp'} 0.10340498
# {'path': 'Keyframes_K01/K01_V005/009675.webp'} 0.103360996
# {'path': 'Keyframes_K04/K04_V003/023729.webp'} 0.10327223
# {'path': 'Keyframes_K02/K02_V028/025643.webp'} 0.10326342
# {'path': 'Keyframes_K02/K02_V020/016852.webp'} 0.10324543
# {'path': 'Keyframes_K04/K04_V010/009664.webp'} 0.10314919
# {'path': 'Keyframes_K04/K04_V003/023683.webp'} 0.10310822
# {'path': 'Keyframes_K03/K03_V001/028835.webp'} 0.103048444
